# %%
import pandas as pd
import requests
import datetime

import pytz

# %%
f = open('../access_token.txt')

# %%
client_id = '08e2f604ed0f49baabd07bccf43cc9b3'
token = f.read()

# %%
input_variables = {
    'Authorization':'Bearer {token}'.format(token=token),
    "Accept": "application/json",
    "Content-Type": "application/json",
}

# %%
today = datetime.datetime.now()
yesterday = today - datetime.timedelta(days=1)
unix = int(yesterday.timestamp())*1000

# %%
r = requests.get('https://api.spotify.com/v1/me/player/recently-played?limit=50&before{time}'.format(time=unix), headers=input_variables)

# %%
data = r.json()

# %%
artis_name = []
album_name = []
song_name = []
played_at = []
release = []

# %%
for song in data['items']:
    artis_name.append(song['track']['album']['artists'][0]['name'])
    album_name.append(song['track']['album']['name'])
    song_name.append(song['track']['name'])
    played_at.append(song['played_at'])
    release.append(song['track']['album']["release_date"])

# %%
df_dict = {
    'song_name':song_name,
    'artis_name':artis_name,
    'album_name':album_name,
    'release':release,
    'played_at':played_at
}

# %%
df = pd.DataFrame(df_dict, columns=['song_name','artis_name','album_name','release','played_at'])

# %% [markdown]
# # __Transfrom__

# %%
df['release'] = df['release'].apply(lambda x : x[:4])
df['release'] = pd.to_datetime(df['release'])
df['release'] = df['release'].dt.year

# %%
df['played_at'] = pd.to_datetime(df['played_at']).dt.tz_convert('Etc/GMT-7')
df['played_at'] = df['played_at'].dt.strftime('%Y-%m-%d %H:%M:%S') # trả về object
df['played_at'] = pd.to_datetime(df['played_at'])

# %%
df = df.sort_values(by=['played_at'], ascending=False)

# %%
print(len(df))
# Out:
# 50

# %%
df.head(50)
# Out:
#                                             song_name         artis_name  \
# 0                                  ウィーアー! (ONE PIECE)    Various Artists
# 1                     Fight Together (From ONE PIECE)    Various Artists
# 2                                       紅蓮華 -TV ver.-               LiSA
# 3                                          departure!      Masatoshi Ono
# 4                               Crazy Rainbow (ワンピース)    Various Artists
# 5                                    Jiyuu no Tsubasa     Linked Horizon
# 6                       Shoukei to Shikabane no Michi     Linked Horizon
# 7                                 Good Morning World!  BURNOUT SYNDROMES
# 8                                        OVER THE TOP   Hiroshi Kitadani
# 9                                departure! - TV Size      Masatoshi Ono
# 10           Netsujou No Spectrum (Nanatsu No Taizai)           Berioska
# 11                       Guren no Yumiya Tv Size Ver.     Linked Horizon
# 12            Shoukei to Shikabane no Michi - Tv Size     Linked Horizon
# 13                      Shinzo wo Sasageyo! - TV Size     Linked Horizon
# 14    Love Dramatic (From "Kaguya-sama: Love is War")          Miura Jam
# 15        Kibou No Uta (Food Wars! Shokugeki No Soma)          Miura Jam
# 16                                     BINKUSUNO SAKE                Ado
# 17                                 We Are (One Piece)          Miura Jam
# 18  Dan Dan Kokoro Hikareteku (From "Dragon Ball GT")          Miura Jam
# 19                    Polaris (Boku No Hero Academia)          Miura Jam
# 20  Braver (From "Angolmois: Record of Mongol Inva...          Miura Jam
# 21                                     Because of you       After School
# 22                                             Heaven              AILEE
# 23                                           Only You             miss A
# 24                                              SPOT!               ZICO
# 25                                           The Boys  Girls' Generation
# 26                                          Energetic          Wanna One
# 27                                               Hush             miss A
# 28                                          Something         Girl's Day
# 29                                        Don't Leave             GD&TOP
# 30                                      Give it to me             SISTAR
# 31                                             NoNoNo              Apink
# 32                                              Alone             SISTAR
# 33                                         Lion Heart  Girls' Generation
# 34                                            Mr. Chu              Apink
# 35                             LET'S NOT FALL IN LOVE            BIGBANG
# 36                                               보여줄게              AILEE
# 37                                          Haru Haru            BIGBANG
# 38                                                Gee  Girls' Generation
# 39                                               STEP               KARA
# 40                                          Up & Down               EXID
# 41                                              Genie  Girls' Generation
# 42                                                Mr.               KARA
# 43                                            Go Away               2NE1
# 44                                          Roly-Poly              T-ARA
# 45                                        I GOT A BOY  Girls' Generation
# 46                                 Bad Girl Good Girl             miss A
# 47                               You and I (Park Bom)               2NE1
# 48                                      I Am The Best               2NE1
# 49                                               FIRE               2NE1
#
#                                            album_name  release  \
# 0     アニソンLive大全集 熱烈!アニソン魂「アニたまLive」vol.1 in AJF 2004     2004
# 1       JAPAN ANIMESONG COLLECTION VOL.47 [アニソン ジャパン]     2012
# 2                                                 紅蓮華     2019
# 3                               “HUNTER×HUNTER”Single     2012
# 4       JAPAN ANIMESONG COLLECTION VOL.22 [アニソン・ジャパン]     2009
# 5                                  Shingeki no Kiseki     2017
# 6                              Shinjitsu eno Shingeki     2019
# 7                                   BURNOUT SYNDROMEZ     2020
# 8                                        OVER THE TOP     2019
# 9                                          departure!     2011
# 10           Netsujou No Spectrum (Nanatsu No Taizai)     2018
# 11                       Guren no Yumiya Tv Size Ver.     2013
# 12            Shoukei to Shikabane no Michi (TV Size)     2019
# 13                      Shinzo wo Sasageyo! (TV Size)     2017
# 14    Love Dramatic (From "Kaguya-sama: Love is War")     2019
# 15        Kibou No Uta (Food Wars! Shokugeki No Soma)     2020
# 16                     UTA'S SONGS ONE PIECE FILM RED     2022
# 17                                 We Are (One Piece)     2021
# 18  Dan Dan Kokoro Hikareteku (From "Dragon Ball GT")     2018
# 19                    Polaris (Boku No Hero Academia)     2019
# 20  Braver (From "Angolmois: Record of Mongol Inva...     2018
# 21                                     Because of You     2009
# 22                                             Heaven     2012
# 23                                             Colors     2015
